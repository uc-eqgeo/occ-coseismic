# %%
import geopandas as gpd
from shapely.geometry import Point
import numpy as np

"""
Take geojson of sites (e.g validation sites) and round their locations to the semi-regular grid for occ
"""

rounding = 1
sites = gpd.read_file('../sites/validation_sites_KC.geojson')
name_col = 'Site'

original_location = sites.geometry
sites['Lon'], sites['Lat'] = sites.geometry.x, sites.geometry.y
sites['geometry'] = sites['geometry'].apply(lambda x: Point(np.round(x.x / rounding) * rounding, np.round(x.y / rounding) * rounding))
sites['rounding_distance'] = sites.geometry.distance(original_location)
if name_col in sites.columns:
    sites = sites.rename(columns={name_col: 'siteId'})
else:
    sites['siteId'] = sites.geometry.apply(lambda x: f"{x.x:.0f}_{x.y:.0f}")

sites.to_file('../sites/validation_sites_KC_1m.geojson', driver="GeoJSON")

# %%
sites
# Out:
#        Id                  siteId       POINT_X       POINT_Y      RI  \
# 0   False      Kaikoura Peninsula  1.658860e+06  5.303084e+06   511.0
# 1   False           Cape Campbell  1.705869e+06  5.377889e+06   357.0
# 2   False   Mataora-Wairau Lagoon  1.693983e+06  5.399980e+06   500.0
# 3   False          Turakirae Head  1.760243e+06  5.411148e+06  2223.0
# 4   False         Mahia Peninsula  2.032365e+06  5.659707e+06  1080.0
# 5   False                 Pakarae  2.057688e+06  5.719895e+06   850.0
# 6   False                  Puatai  2.060584e+06  5.722003e+06   700.0
# 7   False                 Needles  1.696345e+06  5.363881e+06     0.0
# 8   False               Puakimuri  1.807963e+06  5.399687e+06   750.0
# 9   False                Aramoana  1.927458e+06  5.549434e+06  2473.0
# 10  False  Ahuriri_Pak_Subsidence  1.930256e+06  5.625507e+06  1296.0
# 11  False      Ahuriri_Pak_Uplift  1.930600e+06  5.624173e+06  2552.0
# 12  False               Waimarama  1.941991e+06  5.584922e+06     0.0
# 13  False                Glenburn  1.839066e+06  5.421706e+06     0.0
# 14  False               Mataikona  1.876129e+06  5.480787e+06     0.0
# 15  False                Whareama  1.861178e+06  5.454773e+06     0.0
# 16  False              Flat Point  1.848001e+06  5.429924e+06     0.0
# 17  False          Manurewa Point  1.811114e+06  5.402284e+06     0.0
# 18  False              Te Humenga  1.783178e+06  5.400628e+06     0.0
# 19  False               Turakirae  1.760156e+06  5.411130e+06     0.0
# 20  False                Parikawa  1.677565e+06  5.340336e+06     0.0
#
#     RI_Uncert   SED  SED_Uncert       SED_1                         geometry  \
# 0       100.0  0.85        0.10  0.85 +-0.1  POINT (1658860.000 5303084.000)
# 1       100.0  0.00        0.00          NA  POINT (1705869.000 5377889.000)
# 2       160.0 -0.32        0.10  -0.32+-0.1  POINT (1693983.000 5399980.000)
# 3       287.0  6.90        1.50    6.9+-1.5  POINT (1760243.000 5411148.000)
# 4       677.0  2.10        1.00      2.1+-1  POINT (2032365.000 5659707.000)
# 5       450.0  2.70        1.10    2.7+-1.1  POINT (2057688.000 5719895.000)
# 6       180.0  2.90        0.50    2.9+-0.5  POINT (2060584.000 5722003.000)
# 7         0.0  2.20        0.50    2.1+-0.5  POINT (1696345.000 5363881.000)
# 8       150.0  2.00        0.75     2+-0.75  POINT (1807963.000 5399687.000)
# 9      2720.0  2.30        1.00      2.3+-1  POINT (1927458.000 5549434.000)
# 10      752.0 -1.20        0.67   -1.2+-0.7  POINT (1930256.000 5625507.000)
# 11     1031.0  1.75        0.60   1.75+-0.6  POINT (1930600.000 5624173.000)
# 12        0.0  0.00        0.00        None  POINT (1941991.000 5584922.000)
# 13        0.0  0.00        0.00        None  POINT (1839066.000 5421706.000)
# 14        0.0  0.00        0.00        None  POINT (1876129.000 5480787.000)
# 15        0.0  0.00        0.00        None  POINT (1861178.000 5454773.000)
# 16        0.0  0.00        0.00        None  POINT (1848001.000 5429924.000)
# 17        0.0  0.00        0.00        None  POINT (1811114.000 5402284.000)
# 18        0.0  0.00        0.00        None  POINT (1783178.000 5400628.000)
# 19        0.0  0.00        0.00        None  POINT (1760156.000 5411130.000)
# 20        0.0  0.00        0.00        None  POINT (1677565.000 5340336.000)
#
#              Lon           Lat  rounding_distance
# 0   1.658860e+06  5.303084e+06           0.562629
# 1   1.705869e+06  5.377889e+06           0.459655
# 2   1.693983e+06  5.399980e+06           0.430876
# 3   1.760243e+06  5.411148e+06           0.425756
# 4   2.032365e+06  5.659707e+06           0.164960
# 5   2.057688e+06  5.719895e+06           0.311055
# 6   2.060584e+06  5.722003e+06           0.560717
# 7   1.696345e+06  5.363881e+06           0.357271
# 8   1.807963e+06  5.399687e+06           0.505550
# 9   1.927458e+06  5.549434e+06           0.427168
# 10  1.930256e+06  5.625507e+06           0.527264
# 11  1.930600e+06  5.624173e+06           0.372024
# 12  1.941991e+06  5.584922e+06           0.384548
# 13  1.839066e+06  5.421706e+06           0.406333
# 14  1.876129e+06  5.480787e+06           0.298831
# 15  1.861178e+06  5.454773e+06           0.354636
# 16  1.848001e+06  5.429924e+06           0.254929
# 17  1.811114e+06  5.402284e+06           0.156082
# 18  1.783178e+06  5.400628e+06           0.443929
# 19  1.760156e+06  5.411130e+06           0.603916
# 20  1.677565e+06  5.340336e+06           0.291587
